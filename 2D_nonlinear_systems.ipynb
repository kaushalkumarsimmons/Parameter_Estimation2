# %% [markdown]
# ## 2D nonlinear damped oscillators

# %%
import numpy as np
from scipy.integrate import solve_ivp
from scipy.optimize import minimize
import matplotlib.pyplot as plt

# Define the function
def f(t, y, a, b, c, d):
    y1, y2 = y
    return np.array([a * y1**3 + b * y2**3, c * y1**3 + d * y2**3])

# Define the objective function
def objective(x, t, y_data):
    y0 = [2.0, 0.0]  # initial conditions
    sol = solve_ivp(lambda t, y: f(t, y, *x), [t[0], t[-1]], y0, t_eval=t)
    y_pred = sol.y
    return np.sum((y_data - y_pred) ** 2)

# Define parameters
a = -0.1
b = 2.0
c = -2
d = -0.1

t0 = 0.0
tmax = 25.0
y0 = np.array([2, 0])

# Generate noisy data for different noise levels
t = np.linspace(t0, tmax, 1000)

# Plot the results
fig, axs = plt.subplots(4, 2, figsize=(16, 16))
noises = [0.0001, 0.001, 0.01, 0.1]
for i, noise in enumerate(noises):
    row = i
    col = 0
    print(f"Noise: {noise}")
    y_true = solve_ivp(lambda t, y: f(t, y, a, b, c, d), [t0, tmax], y0, t_eval=t).y
    y_data = y_true + noise * np.random.randn(*y_true.shape)

    # Estimate the parameters using the trust region method
    x0 = [-0.087, 1.85, -1.85, -0.088]  # initial guess for a, b, c, d
    res = minimize(lambda x: objective(x, t, y_data), x0, method='trust-constr',
                   bounds=[(-1, None), (-10, None), (-10, None), (-1, None)])
    a_opt, b_opt, c_opt, d_opt = res.x
    print(f"Optimized parameters: a={a_opt:.4f}, b={b_opt:.4f}, c={c_opt:.4f}, d={d_opt:.4f}")
    print(f"True parameters: a={a:.4f}, b={b:.4f}, c={c:.4f}, d={d:.4f}")

    # Solve the differential equation using the optimized parameters
    y0 = np.array([2.0, 0.0])  # initial conditions
    sol = solve_ivp(lambda t, y: f(t, y, a_opt, b_opt, c_opt, d_opt), [t0, tmax], y0, t_eval=t)

    # Compute the MSE and RMSE
    mse = np.mean((y_data - sol.y) ** 2)
    rmse = np.sqrt(mse)
    print(f"MSE: {mse:.4f}")
    print(f"RMSE: {rmse:.4f}")

    # Plot the results
    axs[row, col].plot(t, y_data[0], '.', label='Data')
    axs[row, col].plot(t, y_true[0], '-', label='True x1')
    axs[row, col].plot(t, sol.y[0], '--', label='Estimated x1')
    axs[row, col].plot(t, y_data[1], '.', label='Data')
    axs[row, col].plot(t, y_true[1], '-', label='True x2')
    axs[row, col].plot(t, sol.y[1], '--', label='Estimated x2')
    axs[row, col].set_xlabel('Time')
    axs[row, col].set_ylabel('$x_{k}$')
    #axs[row, col].set_title(f"Noise level = {noise}, RMSE = {rmse:.4f}, MSE = {mse:.4f}")
    axs[row, col].set_title(f"Noise level = {noise}")
    axs[row, col].legend()

    # Plot the position-velocity phase portrait
    ax = axs[row, col+1]
    ax.plot(y_data[0], y_data[1], '.', label='Data')
    ax.plot(y_true[0], y_true[1], '-', label='True')
    ax.plot(sol.y[0], sol.y[1], '--', label='Estimated')
    ax.set_title(f"Noise level = {noise}")
    ax.set_xlabel('Position')
    ax.set_ylabel('Velocity')
    ax.legend()

plt.tight_layout()
plt.show()
# Out:
# Noise: 0.0001
# Optimized parameters: a=-0.1000, b=1.9999, c=-2.0000, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0001
# Noise: 0.001
# Optimized parameters: a=-0.0998, b=1.9999, c=-2.0001, d=-0.1002
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0010
# Noise: 0.01
# Optimized parameters: a=-0.1054, b=2.0047, c=-1.9985, d=-0.0948
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0001
# RMSE: 0.0103
# Noise: 0.1
# Optimized parameters: a=-0.1071, b=2.0185, c=-1.9923, d=-0.0933
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0101
# RMSE: 0.1007

# %% [markdown]
# ## Effects of Gaussian noise under 10 iteration

# %%
import numpy as np
from scipy.integrate import solve_ivp
from scipy.optimize import minimize
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

# Define the function
def f(t, y, a, b, c, d):
    y1, y2 = y
    return np.array([a * y1**3 + b * y2**3, c * y1**3 + d * y2**3])

# Define the objective function
def objective(x, t, y_data):
    y0 = [2.0, 0.0]  # initial conditions
    sol = solve_ivp(lambda t, y: f(t, y, *x), [t[0], t[-1]], y0, t_eval=t)
    y_pred_interpolated = interp1d(sol.t, sol.y, kind='linear', axis=1)(t)
    return np.sum((y_data - y_pred_interpolated) ** 2)

# Define parameters
a = -0.1
b = 2.0
c = -2
d = -0.1

t0 = 0.0
tmax = 25.0
y0 = np.array([2, 0])

# Generate noisy data for different noise levels
t = np.linspace(t0, tmax, 1000)

# Plot the results
fig, axs = plt.subplots(4, 2, figsize=(16, 16))
noises = [0.0001, 0.001, 0.01, 0.1]

num_iterations = 10
avg_mse = np.zeros(num_iterations)
avg_rmse = np.zeros(num_iterations)
avg_a_opt = np.zeros(num_iterations)
avg_b_opt = np.zeros(num_iterations)
avg_c_opt = np.zeros(num_iterations)
avg_d_opt = np.zeros(num_iterations)

for i in range(num_iterations):
    print(f"Iteration: {i+1}")
    mse_values = []
    rmse_values = []

    for j, noise in enumerate(noises):
        row = j
        col = 0
        print(f"Noise: {noise}")
        y_true = solve_ivp(lambda t, y: f(t, y, a, b, c, d), [t0, tmax], y0, t_eval=t).y
        y_data = y_true + noise * np.random.randn(*y_true.shape)

        # Estimate the parameters using the trust region method
        x0 = [-0.087, 1.85, -1.85, -0.088]  # initial guess for a, b, c, d
        res = minimize(lambda x: objective(x, t, y_data), x0, method='trust-constr',
                       bounds=[(-1, None), (-10, None), (-10, None), (-1, None)])
        a_opt, b_opt, c_opt, d_opt = res.x
        print(f"Optimized parameters: a={a_opt:.4f}, b={b_opt:.4f}, c={c_opt:.4f}, d={d_opt:.4f}")
        print(f"True parameters: a={a:.4f}, b={b:.4f}, c={c:.4f}, d={d:.4f}")

        # Solve the differential equation using the optimized parameters
        y0 = np.array([2.0, 0.0])  # initial conditions
        sol = solve_ivp(lambda t, y: f(t, y, a_opt, b_opt, c_opt, d_opt), [t0, tmax], y0, t_eval=t)

        # Compute the MSE and RMSE
        mse = np.mean((y_data - sol.y) ** 2)
        rmse = np.sqrt(mse)
        mse_values.append(mse)
        rmse_values.append(rmse)
        print(f"MSE: {mse:.4f}")
        print(f"RMSE: {rmse:.4f}")

        # Plot the results
        axs[row, col].plot(t, y_data[0], '.', label='Data')
        axs[row, col].plot(t, y_true[0], '-', label='True x1')
        axs[row, col].plot(t, sol.y[0], '--', label='Estimated x1')
        axs[row, col].plot(t, y_data[1], '.', label='Data')
        axs[row, col].plot(t, y_true[1], '-', label='True x2')
        axs[row, col].plot(t, sol.y[1], '--', label='Estimated x2')
        axs[row, col].set_xlabel('Time')
        axs[row, col].set_ylabel('$x_{k}$')
        axs[row, col].set_title(f"Noise level = {noise}")
        axs[row, col].legend()

        # Plot the position-velocity phase portrait
        ax = axs[row, col+1]
        ax.plot(y_data[0], y_data[1], '.', label='Data')
        ax.plot(y_true[0], y_true[1], '-', label='True')
        ax.plot(sol.y[0], sol.y[1], '--', label='Estimated')
        ax.set_title(f"Noise level = {noise}")
        ax.set_xlabel('Position')
        ax.set_ylabel('Velocity')
        ax.legend()

        avg_a_opt[i] += a_opt
        avg_b_opt[i] += b_opt
        avg_c_opt[i] += c_opt
        avg_d_opt[i] += d_opt

    avg_a_opt[i] /= len(noises)
    avg_b_opt[i] /= len(noises)
    avg_c_opt[i] /= len(noises)
    avg_d_opt[i] /= len(noises)

    avg_mse[i] = np.mean(mse_values)
    avg_rmse[i] = np.mean(rmse_values)

print(f"Average optimized parameters: a={np.mean(avg_a_opt):.4f}, b={np.mean(avg_b_opt):.4f}, c={np.mean(avg_c_opt):.4f}, d={np.mean(avg_d_opt):.4f}")
print(f"Average MSE: {np.mean(avg_mse):.4f}")
print(f"Average RMSE: {np.mean(avg_rmse):.4f}")

plt.tight_layout()
plt.show()
# Out:
# Iteration: 1
# Noise: 0.0001
# Optimized parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0001
# Noise: 0.001
# Optimized parameters: a=-0.1001, b=1.9998, c=-2.0000, d=-0.0999
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0010
# Noise: 0.01
# Optimized parameters: a=-0.1001, b=2.0045, c=-1.9982, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0001
# RMSE: 0.0098
# Noise: 0.1
# Optimized parameters: a=-0.1128, b=1.9723, c=-2.0086, d=-0.0864
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0107
# RMSE: 0.1034
# Iteration: 2
# Noise: 0.0001
# Optimized parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0001
# Noise: 0.001
# Optimized parameters: a=-0.0999, b=2.0000, c=-2.0000, d=-0.1001
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0010
# Noise: 0.01
# Optimized parameters: a=-0.0988, b=2.0004, c=-1.9999, d=-0.1012
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0001
# RMSE: 0.0100
# Noise: 0.1
# Optimized parameters: a=-0.0966, b=1.9887, c=-2.0017, d=-0.1028
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0095
# RMSE: 0.0972
# Iteration: 3
# Noise: 0.0001
# Optimized parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0001
# Noise: 0.001
# Optimized parameters: a=-0.0998, b=2.0004, c=-1.9999, d=-0.1002
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0010
# Noise: 0.01
# Optimized parameters: a=-0.0995, b=2.0027, c=-1.9990, d=-0.1006
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0001
# RMSE: 0.0100
# Noise: 0.1
# Optimized parameters: a=-0.1043, b=2.0220, c=-1.9912, d=-0.0962
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0098
# RMSE: 0.0992
# Iteration: 4
# Noise: 0.0001
# Optimized parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0001
# Noise: 0.001
# Optimized parameters: a=-0.1000, b=1.9994, c=-2.0002, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0010
# Noise: 0.01
# Optimized parameters: a=-0.0973, b=1.9990, c=-2.0011, d=-0.1027
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0001
# RMSE: 0.0098
# Noise: 0.1
# Optimized parameters: a=-0.0971, b=1.9258, c=-2.0323, d=-0.1009
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0099
# RMSE: 0.0993
# Iteration: 5
# Noise: 0.0001
# Optimized parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0001
# Noise: 0.001
# Optimized parameters: a=-0.1000, b=1.9998, c=-2.0001, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0010
# Noise: 0.01
# Optimized parameters: a=-0.1005, b=2.0026, c=-1.9989, d=-0.0996
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0001
# RMSE: 0.0097
# Noise: 0.1
# Optimized parameters: a=-0.0969, b=1.9960, c=-2.0033, d=-0.1031
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0102
# RMSE: 0.1010
# Iteration: 6
# Noise: 0.0001
# Optimized parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0001
# Noise: 0.001
# Optimized parameters: a=-0.1001, b=2.0000, c=-2.0000, d=-0.0999
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0010
# Noise: 0.01
# Optimized parameters: a=-0.0989, b=2.0019, c=-1.9994, d=-0.1012
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0001
# RMSE: 0.0101
# Noise: 0.1
# Optimized parameters: a=-0.0961, b=2.0313, c=-1.9815, d=-0.1042
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0100
# RMSE: 0.1000
# Iteration: 7
# Noise: 0.0001
# Optimized parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0001
# Noise: 0.001
# Optimized parameters: a=-0.1001, b=2.0003, c=-1.9999, d=-0.0999
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0010
# Noise: 0.01
# Optimized parameters: a=-0.1008, b=1.9977, c=-2.0006, d=-0.0991
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0001
# RMSE: 0.0102
# Noise: 0.1
# Optimized parameters: a=-0.1087, b=1.9791, c=-2.0045, d=-0.0903
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0097
# RMSE: 0.0984
# Iteration: 8
# Noise: 0.0001
# Optimized parameters: a=-0.1000, b=1.9999, c=-2.0000, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0001
# Noise: 0.001
# Optimized parameters: a=-0.0997, b=1.9999, c=-2.0000, d=-0.1003
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0010
# Noise: 0.01
# Optimized parameters: a=-0.0988, b=1.9984, c=-2.0006, d=-0.1011
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0001
# RMSE: 0.0101
# Noise: 0.1
# Optimized parameters: a=-0.1051, b=2.0287, c=-1.9948, d=-0.0963
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0101
# RMSE: 0.1005
# Iteration: 9
# Noise: 0.0001
# Optimized parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0001
# Noise: 0.001
# Optimized parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0010
# Noise: 0.01
# Optimized parameters: a=-0.1017, b=1.9997, c=-2.0003, d=-0.0983
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0001
# RMSE: 0.0099
# Noise: 0.1
# Optimized parameters: a=-0.1128, b=1.9791, c=-2.0068, d=-0.0866
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0100
# RMSE: 0.1000
# Iteration: 10
# Noise: 0.0001
# Optimized parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0001
# Noise: 0.001
# Optimized parameters: a=-0.1000, b=2.0004, c=-1.9999, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0010
# Noise: 0.01
# Optimized parameters: a=-0.0989, b=1.9948, c=-2.0022, d=-0.1009
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0001
# RMSE: 0.0097
# Noise: 0.1
# Optimized parameters: a=-0.1054, b=1.9570, c=-2.0177, d=-0.0936
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0096
# RMSE: 0.0981
# Average optimized parameters: a=-0.1008, b=1.9970, c=-2.0011, d=-0.0991
# Average MSE: 0.0025
# Average RMSE: 0.0277
# /tmp/ipykernel_141791/3494163233.py:115: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ## Effects of colored noise (pink noise)

# %%
import numpy as np
from scipy.integrate import solve_ivp
from scipy.optimize import minimize
import matplotlib.pyplot as plt

# Define the function
def f(t, y, a, b, c, d):
    y1, y2 = y
    return np.array([a * y1**3 + b * y2**3, c * y1**3 + d * y2**3])

# Define the objective function
def objective(x, t, y_data):
    y0 = [2.0, 0.0]  # initial conditions
    sol = solve_ivp(lambda t, y: f(t, y, *x), [t[0], t[-1]], y0, t_eval=t)
    y_pred = sol.y
    return np.sum((y_data - y_pred) ** 2)

# Define parameters
a = -0.1
b = 2.0
c = -2
d = -0.1

t0 = 0.0
tmax = 25.0
y0 = np.array([2, 0])

# Generate noisy data for different noise levels
t = np.linspace(t0, tmax, 1000)

# Plot the results
fig, axs = plt.subplots(4, 2, figsize=(16, 16))
noises = [0.0001, 0.001, 0.01, 0.1]

num_iterations = 10
avg_mse = np.zeros(num_iterations)
avg_rmse = np.zeros(num_iterations)
avg_a_opt = np.zeros(num_iterations)
avg_b_opt = np.zeros(num_iterations)
avg_c_opt = np.zeros(num_iterations)
avg_d_opt = np.zeros(num_iterations)

for i in range(num_iterations):
    print(f"Iteration: {i+1}")
    mse_values = []
    rmse_values = []

    for j, noise in enumerate(noises):
        row = j
        col = 0
        print(f"Noise: {noise}")
        y_true = solve_ivp(lambda t, y: f(t, y, a, b, c, d), [t0, tmax], y0, t_eval=t).y

        # Generate colored noise (pink noise)
        n = len(t)
        dt = t[1] - t[0]
        freq = np.fft.fftfreq(n, dt)
        power_spectrum = np.sqrt(1 / np.abs(freq))
        power_spectrum[0] = 0
        colored_noise = np.fft.ifft(np.fft.fft(np.random.normal(0, 1, n)) * power_spectrum).real

        desired_length = y_true.shape[1]  # Adjusted to match the length of the true solution
        colored_noise = colored_noise[:desired_length]

        y_data = y_true + noise * colored_noise

        # Estimate the parameters using the trust region method
        x0 = [-0.087, 1.85, -1.85, -0.088]  # initial guess for a, b, c, d
        res = minimize(lambda x: objective(x, t, y_data), x0, method='trust-constr',
                       bounds=[(-1, None), (-10, None), (-10, None), (-1, None)])
        a_opt, b_opt, c_opt, d_opt = res.x
        print(f"Optimized parameters: a={a_opt:.4f}, b={b_opt:.4f}, c={c_opt:.4f}, d={d_opt:.4f}")
        print(f"True parameters: a={a:.4f}, b={b:.4f}, c={c:.4f}, d={d:.4f}")

        # Solve the differential equation using the optimized parameters
        y0 = np.array([2.0, 0.0])  # initial conditions
        sol = solve_ivp(lambda t, y: f(t, y, a_opt, b_opt, c_opt, d_opt), [t0, tmax], y0, t_eval=t)

        # Compute the MSE and RMSE
        mse = np.mean((y_data - sol.y) ** 2)
        rmse = np.sqrt(mse)
        mse_values.append(mse)
        rmse_values.append(rmse)
        print(f"MSE: {mse:.4f}")
        print(f"RMSE: {rmse:.4f}")

        # Plot the results
        axs[row, col].plot(t, y_data[0], '.', label='Data')
        axs[row, col].plot(t, y_true[0], '-', label='True x1')
        axs[row, col].plot(t, sol.y[0], '--', label='Estimated x1')
        axs[row, col].plot(t, y_data[1], '.', label='Data')
        axs[row, col].plot(t, y_true[1], '-', label='True x2')
        axs[row, col].plot(t, sol.y[1], '--', label='Estimated x2')
        axs[row, col].set_xlabel('Time')
        axs[row, col].set_ylabel('$x_{k}$')
        axs[row, col].set_title(f"Noise level = {noise}")
        axs[row, col].legend()

        # Plot the position-velocity phase portrait
        ax = axs[row, col+1]
        ax.plot(y_data[0], y_data[1], '.', label='Data')
        ax.plot(y_true[0], y_true[1], '-', label='True')
        ax.plot(sol.y[0], sol.y[1], '--', label='Estimated')
        ax.set_title(f"Noise level = {noise}")
        ax.set_xlabel('Position')
        ax.set_ylabel('Velocity')
        ax.legend()

        avg_a_opt[i] += a_opt
        avg_b_opt[i] += b_opt
        avg_c_opt[i] += c_opt
        avg_d_opt[i] += d_opt

    avg_a_opt[i] /= len(noises)
    avg_b_opt[i] /= len(noises)
    avg_c_opt[i] /= len(noises)
    avg_d_opt[i] /= len(noises)

    avg_mse[i] = np.mean(mse_values)
    avg_rmse[i] = np.mean(rmse_values)

print(f"Average optimized parameters: a={np.mean(avg_a_opt):.4f}, b={np.mean(avg_b_opt):.4f}, c={np.mean(avg_c_opt):.4f}, d={np.mean(avg_d_opt):.4f}")
print(f"Average MSE: {np.mean(avg_mse):.4f}")
print(f"Average RMSE: {np.mean(avg_rmse):.4f}")

plt.tight_layout()
plt.show()
# Out:
# Iteration: 1
# Noise: 0.0001
# /tmp/ipykernel_141791/1370872148.py:58: RuntimeWarning: divide by zero encountered in true_divide
#   power_spectrum = np.sqrt(1 / np.abs(freq))
# Optimized parameters: a=-0.1000, b=1.9999, c=-2.0000, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0001
# Noise: 0.001
# Optimized parameters: a=-0.1001, b=1.9992, c=-2.0004, d=-0.0999
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0006
# Noise: 0.01
# Optimized parameters: a=-0.1020, b=1.9957, c=-2.0012, d=-0.0979
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0057
# Noise: 0.1
# Optimized parameters: a=-0.0968, b=1.9378, c=-2.0256, d=-0.1012
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0033
# RMSE: 0.0573
# Iteration: 2
# Noise: 0.0001
# Optimized parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0001
# Noise: 0.001
# Optimized parameters: a=-0.1001, b=2.0004, c=-2.0000, d=-0.0999
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0006
# Noise: 0.01
# Optimized parameters: a=-0.1034, b=1.9921, c=-2.0021, d=-0.0963
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0053
# Noise: 0.1
# Optimized parameters: a=-0.0974, b=2.1004, c=-1.9687, d=-0.1065
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0040
# RMSE: 0.0634
# Iteration: 3
# Noise: 0.0001
# Optimized parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0000
# Noise: 0.001
# Optimized parameters: a=-0.1004, b=1.9993, c=-2.0002, d=-0.0996
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0006
# Noise: 0.01
# Optimized parameters: a=-0.0990, b=2.0108, c=-1.9979, d=-0.1016
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0057
# Noise: 0.1
# Optimized parameters: a=-0.1030, b=1.9691, c=-2.0048, d=-0.0955
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0031
# RMSE: 0.0561
# Iteration: 4
# Noise: 0.0001
# Optimized parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0001
# Noise: 0.001
# Optimized parameters: a=-0.1000, b=1.9996, c=-2.0001, d=-0.0999
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0005
# Noise: 0.01
# Optimized parameters: a=-0.0967, b=2.0027, c=-1.9988, d=-0.1033
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0055
# Noise: 0.1
# Optimized parameters: a=-0.0965, b=1.9467, c=-2.0201, d=-0.1015
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0033
# RMSE: 0.0574
# Iteration: 5
# Noise: 0.0001
# Optimized parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0001
# Noise: 0.001
# Optimized parameters: a=-0.0999, b=2.0007, c=-1.9997, d=-0.1001
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0006
# Noise: 0.01
# Optimized parameters: a=-0.0999, b=2.0083, c=-1.9971, d=-0.1004
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0062
# Noise: 0.1
# Optimized parameters: a=-0.1129, b=2.0076, c=-2.0001, d=-0.0878
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0031
# RMSE: 0.0555
# Iteration: 6
# Noise: 0.0001
# Optimized parameters: a=-0.1000, b=2.0001, c=-2.0000, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0000
# Noise: 0.001
# Optimized parameters: a=-0.0996, b=2.0022, c=-1.9993, d=-0.1004
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0006
# Noise: 0.01
# Optimized parameters: a=-0.0991, b=1.9992, c=-2.0005, d=-0.1009
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0048
# Noise: 0.1
# Optimized parameters: a=-0.1131, b=1.9140, c=-2.0355, d=-0.0852
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0032
# RMSE: 0.0564
# Iteration: 7
# Noise: 0.0001
# Optimized parameters: a=-0.1000, b=2.0001, c=-2.0000, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0001
# Noise: 0.001
# Optimized parameters: a=-0.1001, b=2.0003, c=-2.0000, d=-0.0999
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0006
# Noise: 0.01
# Optimized parameters: a=-0.1039, b=2.0053, c=-1.9990, d=-0.0964
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0059
# Noise: 0.1
# Optimized parameters: a=-0.1028, b=1.9023, c=-2.0242, d=-0.0929
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0028
# RMSE: 0.0525
# Iteration: 8
# Noise: 0.0001
# Optimized parameters: a=-0.1000, b=2.0001, c=-2.0000, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0001
# Noise: 0.001
# Optimized parameters: a=-0.1000, b=2.0002, c=-2.0000, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0006
# Noise: 0.01
# Optimized parameters: a=-0.0980, b=2.0123, c=-1.9955, d=-0.1024
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0058
# Noise: 0.1
# Optimized parameters: a=-0.0966, b=2.0452, c=-1.9817, d=-0.1047
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0028
# RMSE: 0.0531
# Iteration: 9
# Noise: 0.0001
# Optimized parameters: a=-0.1000, b=1.9999, c=-2.0000, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0001
# Noise: 0.001
# Optimized parameters: a=-0.0997, b=2.0004, c=-1.9998, d=-0.1003
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0005
# Noise: 0.01
# Optimized parameters: a=-0.0983, b=1.9963, c=-2.0012, d=-0.1015
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0055
# Noise: 0.1
# Optimized parameters: a=-0.1130, b=1.9534, c=-2.0203, d=-0.0861
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0039
# RMSE: 0.0624
# Iteration: 10
# Noise: 0.0001
# Optimized parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0001
# Noise: 0.001
# Optimized parameters: a=-0.1000, b=2.0004, c=-1.9999, d=-0.1000
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0006
# Noise: 0.01
# Optimized parameters: a=-0.1003, b=1.9970, c=-2.0011, d=-0.0996
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0000
# RMSE: 0.0048
# Noise: 0.1
# Optimized parameters: a=-0.1133, b=1.9362, c=-2.0330, d=-0.0862
# True parameters: a=-0.1000, b=2.0000, c=-2.0000, d=-0.1000
# MSE: 0.0031
# RMSE: 0.0553
# Average optimized parameters: a=-0.1011, b=1.9934, c=-2.0027, d=-0.0987
# Average MSE: 0.0008
# Average RMSE: 0.0158
# /tmp/ipykernel_141791/1370872148.py:126: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()
